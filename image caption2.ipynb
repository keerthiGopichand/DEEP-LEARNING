# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Activation
import matplotlib.pyplot as plt
from keras.datasets import mnist

# %%
  (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train.astype("float32")/255.0
x_test = x_test.astype("float32")/255.0

# %%
gray_scale = 255
x_train /= gray_scale
x_test /= gray_scale

# %%
print("Feature matrix:", x_train.shape)
print("Target matrix:", x_test.shape)
print("Feature matrix:", y_train.shape)
print("Target matrix:", y_test.shape)
# Out:
# Feature matrix: (60000, 28, 28)
# Target matrix: (10000, 28, 28)
# Feature matrix: (60000,)
# Target matrix: (10000,)

# %%
fig, ax = plt.subplots(10,10)
k=0
for i in range(10):
    for j in range(10):
        ax[i][j].imshow(x_train[k].reshape(28,28), aspect='auto')
        k += 1
plt.show()

# %%
model = Sequential([
    Flatten(input_shape = (28,28)),
    Dense(256, activation='sigmoid'),
    Dense(128, activation ='sigmoid'),
    Dense(10, activation ='sigmoid'),
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics= ['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, batch_size=2000, validation_split= 0.2)
# Out:
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.1077 - loss: 2.3313 - val_accuracy: 0.1060 - val_loss: 2.3022
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.1032 - loss: 2.3031 - val_accuracy: 0.1060 - val_loss: 2.3018
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.1162 - loss: 2.3002 - val_accuracy: 0.1060 - val_loss: 2.2993
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.1167 - loss: 2.2977 - val_accuracy: 0.2035 - val_loss: 2.2969
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.1246 - loss: 2.2963 - val_accuracy: 0.1060 - val_loss: 2.2969
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.1206 - loss: 2.2946 - val_accuracy: 0.0956 - val_loss: 2.2959
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.1241 - loss: 2.2925 - val_accuracy: 0.2002 - val_loss: 2.2902
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.1525 - loss: 2.2890 - val_accuracy: 0.1447 - val_loss: 2.2851
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.1660 - loss: 2.2841 - val_accuracy: 0.1060 - val_loss: 2.2801
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.1532 - loss: 2.2787 - val_accuracy: 0.1082 - val_loss: 2.2747

# %%
result = model.evaluate(x_test, y_test, verbose=0)

# %%
result
# Out:
# [2.2735207080841064, 0.1185000017285347]

# %%
result1 = model.evaluate(x_test, y_test, verbose =1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1185 - loss: 2.2762

# %%
result1
# Out:
# [2.2735207080841064, 0.1185000017285347]

# %%
results = model.eveluate(x_
